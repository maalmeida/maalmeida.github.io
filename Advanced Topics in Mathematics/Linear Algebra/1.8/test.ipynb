# %%
# Number 5
import numpy as np
from sympy import Matrix, pprint

# Define your matrix (example: a 3x4 augmented matrix)
# The matrix is entered as a list of lists, where each inner list is a row
A = Matrix([
    [1,-5,-7,-2],
    [-3,7,5,-2],
])

pprint(A.rref()[0])
# Out:
# ⎡1  0  3  3⎤
# ⎢          ⎥
# ⎣0  1  2  1⎦

# %% [markdown]
# The solution is, then,
# $$ \vec{x}
# = \begin{bmatrix} -3x_3 - 3 \\ -2x_3 - 1 \\ x_3 \end{bmatrix}
# = x_3 \begin{bmatrix} -3 \\ -2 \\ 1 \end{bmatrix} + \begin{bmatrix} 3 \\ 1 \\ 0 \end{bmatrix}
# $$
#
# This represents a line in $\mathbb{R}^3$ passing through $\begin{bmatrix} 3 \\ 1 \\ 0 \end{bmatrix}$, which represents one possible solution that maps to $\mathbf{b}$.
